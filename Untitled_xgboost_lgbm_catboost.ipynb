# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import pickle
from sklearn.neural_network import MLPRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor, GradientBoostingRegressor
from catboost import CatBoostRegressor
from lightgbm import LGBMRegressor
from xgboost import XGBRegressor
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import  LogisticRegression
from sklearn.model_selection import cross_val_score

# %%
test=pd.read_csv('train.csv')
len(test)
# Out:
# 1460

# %%
train=pd.read_csv('train.csv')
test=pd.read_csv('test.csv')
train['type']='train'
test['type']='test'
sample=pd.read_csv('sample_submission.csv')
df=pd.concat([train,test])

# %%
print(df.info())

print(df.describe())
df.apply(lambda x: x.isnull().sum(axis=0))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2919 entries, 0 to 1458
# Data columns (total 82 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             2919 non-null   int64
#  1   MSSubClass     2919 non-null   int64
#  2   MSZoning       2915 non-null   object
#  3   LotFrontage    2433 non-null   float64
#  4   LotArea        2919 non-null   int64
#  5   Street         2919 non-null   object
#  6   Alley          198 non-null    object
#  7   LotShape       2919 non-null   object
#  8   LandContour    2919 non-null   object
#  9   Utilities      2917 non-null   object
#  10  LotConfig      2919 non-null   object
#  11  LandSlope      2919 non-null   object
#  12  Neighborhood   2919 non-null   object
#  13  Condition1     2919 non-null   object
#  14  Condition2     2919 non-null   object
#  15  BldgType       2919 non-null   object
#  16  HouseStyle     2919 non-null   object
#  17  OverallQual    2919 non-null   int64
#  18  OverallCond    2919 non-null   int64
#  19  YearBuilt      2919 non-null   int64
#  20  YearRemodAdd   2919 non-null   int64
#  21  RoofStyle      2919 non-null   object
#  22  RoofMatl       2919 non-null   object
#  23  Exterior1st    2918 non-null   object
#  24  Exterior2nd    2918 non-null   object
#  25  MasVnrType     2895 non-null   object
#  26  MasVnrArea     2896 non-null   float64
#  27  ExterQual      2919 non-null   object
#  28  ExterCond      2919 non-null   object
#  29  Foundation     2919 non-null   object
#  30  BsmtQual       2838 non-null   object
#  31  BsmtCond       2837 non-null   object
#  32  BsmtExposure   2837 non-null   object
#  33  BsmtFinType1   2840 non-null   object
#  34  BsmtFinSF1     2918 non-null   float64
#  35  BsmtFinType2   2839 non-null   object
#  36  BsmtFinSF2     2918 non-null   float64
#  37  BsmtUnfSF      2918 non-null   float64
#  38  TotalBsmtSF    2918 non-null   float64
#  39  Heating        2919 non-null   object
#  40  HeatingQC      2919 non-null   object
#  41  CentralAir     2919 non-null   object
#  42  Electrical     2918 non-null   object
#  43  1stFlrSF       2919 non-null   int64
#  44  2ndFlrSF       2919 non-null   int64
#  45  LowQualFinSF   2919 non-null   int64
#  46  GrLivArea      2919 non-null   int64
#  47  BsmtFullBath   2917 non-null   float64
#  48  BsmtHalfBath   2917 non-null   float64
#  49  FullBath       2919 non-null   int64
#  50  HalfBath       2919 non-null   int64
#  51  BedroomAbvGr   2919 non-null   int64
#  52  KitchenAbvGr   2919 non-null   int64
#  53  KitchenQual    2918 non-null   object
#  54  TotRmsAbvGrd   2919 non-null   int64
#  55  Functional     2917 non-null   object
#  56  Fireplaces     2919 non-null   int64
#  57  FireplaceQu    1499 non-null   object
#  58  GarageType     2762 non-null   object
#  59  GarageYrBlt    2760 non-null   float64
#  60  GarageFinish   2760 non-null   object
#  61  GarageCars     2918 non-null   float64
#  62  GarageArea     2918 non-null   float64
#  63  GarageQual     2760 non-null   object
#  64  GarageCond     2760 non-null   object
#  65  PavedDrive     2919 non-null   object
#  66  WoodDeckSF     2919 non-null   int64
#  67  OpenPorchSF    2919 non-null   int64
#  68  EnclosedPorch  2919 non-null   int64
#  69  3SsnPorch      2919 non-null   int64
#  70  ScreenPorch    2919 non-null   int64
#  71  PoolArea       2919 non-null   int64
#  72  PoolQC         10 non-null     object
#  73  Fence          571 non-null    object
#  74  MiscFeature    105 non-null    object
#  75  MiscVal        2919 non-null   int64
#  76  MoSold         2919 non-null   int64
#  77  YrSold         2919 non-null   int64
#  78  SaleType       2918 non-null   object
#  79  SaleCondition  2919 non-null   object
#  80  SalePrice      1460 non-null   float64
#  81  type           2919 non-null   object
# dtypes: float64(12), int64(26), object(44)
# memory usage: 1.8+ MB
# None
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  2919.000000  2919.000000  2433.000000    2919.000000  2919.000000
# mean   1460.000000    57.137718    69.305795   10168.114080     6.089072
# std     842.787043    42.517628    23.344905    7886.996359     1.409947
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     730.500000    20.000000    59.000000    7478.000000     5.000000
# 50%    1460.000000    50.000000    68.000000    9453.000000     6.000000
# 75%    2189.500000    70.000000    80.000000   11570.000000     7.000000
# max    2919.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  2919.000000  2919.000000   2919.000000  2896.000000  2918.000000  ...
# mean      5.564577  1971.312778   1984.264474   102.201312   441.423235  ...
# std       1.113131    30.291442     20.894344   179.334253   455.610826  ...
# min       1.000000  1872.000000   1950.000000     0.000000     0.000000  ...
# 25%       5.000000  1953.500000   1965.000000     0.000000     0.000000  ...
# 50%       5.000000  1973.000000   1993.000000     0.000000   368.500000  ...
# 75%       6.000000  2001.000000   2004.000000   164.000000   733.000000  ...
# max       9.000000  2010.000000   2010.000000  1600.000000  5644.000000  ...
#
#         WoodDeckSF  OpenPorchSF  EnclosedPorch    3SsnPorch  ScreenPorch  \
# count  2919.000000  2919.000000    2919.000000  2919.000000  2919.000000
# mean     93.709832    47.486811      23.098321     2.602261    16.062350
# std     126.526589    67.575493      64.244246    25.188169    56.184365
# min       0.000000     0.000000       0.000000     0.000000     0.000000
# 25%       0.000000     0.000000       0.000000     0.000000     0.000000
# 50%       0.000000    26.000000       0.000000     0.000000     0.000000
# 75%     168.000000    70.000000       0.000000     0.000000     0.000000
# max    1424.000000   742.000000    1012.000000   508.000000   576.000000
#
#           PoolArea       MiscVal       MoSold       YrSold      SalePrice
# count  2919.000000   2919.000000  2919.000000  2919.000000    1460.000000
# mean      2.251799     50.825968     6.213087  2007.792737  180921.195890
# std      35.663946    567.402211     2.714762     1.314964   79442.502883
# min       0.000000      0.000000     1.000000  2006.000000   34900.000000
# 25%       0.000000      0.000000     4.000000  2007.000000  129975.000000
# 50%       0.000000      0.000000     6.000000  2008.000000  163000.000000
# 75%       0.000000      0.000000     8.000000  2009.000000  214000.000000
# max     800.000000  17000.000000    12.000000  2010.000000  755000.000000
#
# [8 rows x 38 columns]
# Id                  0
# MSSubClass          0
# MSZoning            4
# LotFrontage       486
# LotArea             0
#                  ...
# YrSold              0
# SaleType            1
# SaleCondition       0
# SalePrice        1459
# type                0
# Length: 82, dtype: int64

# %%
categorical_vars= df.select_dtypes(include=['object']).columns
numerical_vars = df.select_dtypes(exclude=['object']).columns
categorical_vars=categorical_vars.drop(['type'])
#train[categorical_vars].describe().T

# %%
categorical_vars
# Out:
# Index(['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature',
#        'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
##missing value correction
#columns to check- PoolQC , Fence , MiscFeature, GarageCond, GarageQual, GarageFinish, GarageYrBlt , GarageType, Electrical 
#FireplaceQu , BsmtFinType2, BsmtFinType1, BsmtExposure, BsmtCond , BsmtQual, MasVnrType, MasVnrArea,  Alley, LotFrontage

train['BsmtExposure'].value_counts().index[0]
train['GarageYrBlt'].median()
#train['LotFrontage']
import seaborn as sns
from matplotlib.pyplot import yticks, xticks, subplots, set_cmap
import matplotlib.pyplot as plt
for i in categorical_vars:
    plt.figure(figsize=(11,11))
    sns.boxplot(x=train[i],y=train['LotFrontage'])
    plt.show()
    plt.close()
#train[train['LotFrontage']
corrmat = train.corr().round(1)
top_corr_features = corrmat.index
plt.figure(figsize=(20,20))
#plot heat map
g=sns.heatmap(corrmat,annot=True,cmap="RdYlGn")
train['Electrical'].value_counts()
train_null_counts=train.apply(lambda x: x.isnull().sum(axis=0))

# %%
#missing value imputation for both train & test

df['PoolQC'].fillna('NA',inplace=True)
df['Fence'].fillna('None',inplace=True)
df['MiscFeature'].fillna('NA',inplace=True)
df['GarageCond'].fillna('NA',inplace=True)
df['GarageQual'].fillna('NA',inplace=True)
df['GarageFinish'].fillna('NA',inplace=True)
df['GarageYrBlt'].fillna(df['YearBuilt'],inplace=True)
df['GarageType'].fillna('NA',inplace=True)
df['FireplaceQu'].fillna('NA',inplace=True)
df['BsmtFinType2'].fillna('NA',inplace=True)
df['Electrical'].fillna(df['Electrical'].value_counts().index[0],inplace=True)
df['BsmtFinType1'].fillna('NA',inplace=True)
df['BsmtExposure']=np.where((df['BsmtExposure'].isnull()) & (df['BsmtFinType1']=='NA'),'NA',df['BsmtExposure'])
df['BsmtExposure'].fillna(df['BsmtExposure'].value_counts().index[0],inplace=True)
df['BsmtQual'].fillna('NA',inplace=True)
df['BsmtCond'].fillna('NA',inplace=True)
df['MasVnrType'].fillna('None',inplace=True)
df['MasVnrArea'].fillna(0.0,inplace=True)
df['Alley'].fillna('NA',inplace=True) 
df['LotFrontage']=np.where((df['LotFrontage'].isnull()) & (df['Alley']=='NA'),df[df['Alley']=='NA'].LotFrontage.mean(),df['LotFrontage'] )
df['LotFrontage']=np.where((df['LotFrontage'].isnull()) & (df['Alley']=='Grvl'),df[df['Alley']=='Grvl'].LotFrontage.mean(),df['LotFrontage'] )
df['LotFrontage']=np.where((df['LotFrontage'].isnull()) & (df['Alley']=='Pave'),df[df['Alley']=='Pave'].LotFrontage.mean(),df['LotFrontage'] )

#MSZoning , Utilities, Exterior2nd, BsmtFinSF1,BsmtFinSF2,
# BsmtHalfBath, GarageArea
df['Exterior1st'].fillna(df['Exterior1st'].value_counts().index[0],inplace=True)
df['BsmtUnfSF'].fillna(0.0,inplace=True)
df['TotalBsmtSF'].fillna(0.0,inplace=True)
df['BsmtFullBath'].fillna(0.0,inplace=True)
df['KitchenQual'].fillna('TA',inplace=True)
df['Functional'].fillna('Typ',inplace=True)
df['GarageCars'].fillna(0.0,inplace=True)
df['MSZoning'].fillna(df['MSZoning'].value_counts().index[0],inplace=True)
df['Utilities'].fillna(df['Utilities'].value_counts().index[0],inplace=True)
df['Exterior2nd'].fillna(df['Exterior2nd'].value_counts().index[0],inplace=True)
df['BsmtFinSF1'].fillna(0.0,inplace=True)
df['BsmtFinSF2'].fillna(0.0,inplace=True)
df['BsmtHalfBath'].fillna(0.0,inplace=True)
df['GarageArea'].fillna(0.0,inplace=True)

# %%
df['BsmtHalfBath'].value_counts(dropna=False)
# Out:
# 0.0    2744
# 1.0     171
# 2.0       4
# Name: BsmtHalfBath, dtype: int64

# %%
#One Hot Encoding of the Categorical features 
print(train)
list_df=[]
list_df.append(df)
for i in categorical_vars:
    locals()['df_' + str(i)]=pd.get_dummies(df[i])
    list_df.append(locals()['df_' + str(i)])
train.drop(categorical_vars,axis=1,inplace=True)
list_df.append(df)
df=pd.concat(list_df,axis=1)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolQC  Fence MiscFeature MiscVal MoSold  \
# 0            Lvl    AllPub  ...    NaN    NaN         NaN       0      2
# 1            Lvl    AllPub  ...    NaN    NaN         NaN       0      5
# 2            Lvl    AllPub  ...    NaN    NaN         NaN       0      9
# 3            Lvl    AllPub  ...    NaN    NaN         NaN       0      2
# 4            Lvl    AllPub  ...    NaN    NaN         NaN       0     12
# ...          ...       ...  ...    ...    ...         ...     ...    ...
# 1455         Lvl    AllPub  ...    NaN    NaN         NaN       0      8
# 1456         Lvl    AllPub  ...    NaN  MnPrv         NaN       0      2
# 1457         Lvl    AllPub  ...    NaN  GdPrv        Shed    2500      5
# 1458         Lvl    AllPub  ...    NaN    NaN         NaN       0      4
# 1459         Lvl    AllPub  ...    NaN    NaN         NaN       0      6
#
#      YrSold SaleType  SaleCondition  SalePrice   type
# 0      2008       WD         Normal     208500  train
# 1      2007       WD         Normal     181500  train
# 2      2008       WD         Normal     223500  train
# 3      2006       WD        Abnorml     140000  train
# 4      2008       WD         Normal     250000  train
# ...     ...      ...            ...        ...    ...
# 1455   2007       WD         Normal     175000  train
# 1456   2010       WD         Normal     210000  train
# 1457   2010       WD         Normal     266500  train
# 1458   2010       WD         Normal     142125  train
# 1459   2008       WD         Normal     147500  train
#
# [1460 rows x 82 columns]

# %%
#df.reset_index(inplace=True)
#df.drop(['level_0','index'],axis=1,inplace=True)
df.shape
# Out:
# (2919, 430)

# %%
train=df.head(1459)
test=df.tail(1459)

train.drop(['type'],axis=1,inplace=True)
test.drop(['type'],axis=1,inplace=True)
# Out:
# C:\Users\Ankita\Anaconda3\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
#check correlation
corrmat = train.corr().round(1)
top_corr_features = corrmat.index
plt.figure(figsize=(20,20))
#plot heat map
g=sns.heatmap(corrmat,annot=True,cmap="RdYlGn")

# %%
#drop correlated columns
columns = np.full((corrmat.shape[0],), True, dtype=bool)
for i in range(corrmat.shape[0]):
    for j in range(i+1, corrmat.shape[0]):
        if corrmat.iloc[i,j] >= 0.9:
            if columns[j]:
                columns[j] = False
selected_columns = train.columns[columns]
train = train[selected_columns]

# %%
len(selected_columns)

# %%
selected_columns = train.columns[1:-1]
import statsmodels.api as sm
def backwardElimination(x, Y, sl, columns):
    numVars = len(x[0])
    for i in range(0, numVars):
        regressor_OLS = sm.OLS(Y, x).fit()
        maxVar = max(regressor_OLS.pvalues).astype(float)
        if maxVar > sl:
            for j in range(0, numVars - i):
                try:
                    if (regressor_OLS.pvalues[j].astype(float) == maxVar):
                        x = np.delete(x, j, 1)
                        columns = np.delete(columns, j)
                except:
                    continue
                    
    regressor_OLS.summary()
    return x, columns
SL = 0.05
data_modeled, selected_columns = backwardElimination(train.iloc[:,1:-1].values, train.iloc[:,-1].values, SL, selected_columns)

# %%
len(selected_columns)

# %%
len(selected_columns)
result = pd.DataFrame()
result['SalePrice'] = train.iloc[:,-1]
data = pd.DataFrame(data = data_modeled, columns = selected_columns)

# %%
selected_columns

# %%
#split_data
x_train, x_test, y_train, y_test = train_test_split(data.values,result.values, test_size = 0.2)

# %%
scaler = StandardScaler()   
scaler=scaler.partial_fit(x_train)
pickle.dump(scaler,open('scaler.pkl','wb'))

scale=pickle.load(open('scaler.pkl','rb'))
x_train = scaler.transform(x_train)
x_test= scaler.transform(x_test)

# %%
names = ["GBM","XGB","LGBM"]
#XGBRegressor(max_delta_step=2,scale_pos_weight=100)   -  "XGB"
regressors = [GradientBoostingRegressor(n_estimators=100,random_state=0,verbose=1),
    XGBRegressor(max_delta_step=2,scale_pos_weight=100) ,
    LGBMRegressor(n_estimators=100,random_state=0)]

# %%
rmse=[]
#num_leaves=150, objective='regression',max_depth=7,learning_rate=.05,max_bin=200
for name,model in zip(names,regressors):
    print(name, model)
    model.fit(np.array(x_train), y_train)
    score = model.score(np.array(x_test), y_test)
    y_pred=model.predict(x_test)
    score=cross_val_score(model, x_test, y_test, cv=5, scoring='neg_root_mean_squared_error')
    print('Rmse',score.mean())
    rmse.append(score.mean())

# %%
from sklearn.model_selection import GridSearchCV
parameters = {'max_depth':[3,5,7],'min_samples_split':[2,5,10], 'max_features':[3,4],'n_estimators':[100,150,200,250]}
model=XGBRegressor(max_delta_step=2,scale_pos_weight=100)
model = GridSearchCV(model, param_grid=parameters,cv=5,verbose=10,scoring='neg_root_mean_squared_error')
print(model)
model.fit(x_train, y_train)

#score = model.score(np.array(x_test), y_test)
#y_pred=model.predict(x_test)
# Out:
# GridSearchCV(cv=5, error_score=nan,
#              estimator=XGBRegressor(base_score=0.5, booster='gbtree',
#                                     colsample_bylevel=1, colsample_bynode=1,
#                                     colsample_bytree=1, gamma=0,
#                                     importance_type='gain', learning_rate=0.1,
#                                     max_delta_step=2, max_depth=3,
#                                     min_child_weight=1, missing=None,
#                                     n_estimators=100, n_jobs=1, nthread=None,
#                                     objective='reg:linear', random_state=0,
#                                     reg_alpha=0, reg_lambda=1,
#                                     scale_pos_weight=100, seed=None,
#                                     silent=None, subsample=1, verbosity=1),
#              iid='deprecated', n_jobs=None,
#              param_grid={'max_depth': [3, 5, 7], 'max_features': [3, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [100, 150, 200, 250]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring='neg_root_mean_squared_error', verbose=10)
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# [CV] max_depth=3, max_features=3, min_samples_split=2, n_estimators=100
# [22:27:26] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  max_depth=3, max_features=3, min_samples_split=2, n_estimators=100, score=-0.065, total=   0.3s
# [CV] max_depth=3, max_features=3, min_samples_split=2, n_estimators=100
# [22:27:26] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.2s remaining:    0.0s
# [CV]  max_depth=3, max_features=3, min_samples_split=2, n_estimators=100, score=-0.065, total=   0.2s
# [CV] max_depth=3, max_features=3, min_samples_split=2, n_estimators=100
# [22:27:27] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.4s remaining:    0.0s
# [CV]  max_depth=3, max_features=3, min_samples_split=2, n_estimators=100, score=-0.005, total=   0.2s
# [CV] max_depth=3, max_features=3, min_samples_split=2, n_estimators=100
# [22:27:27] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.7s remaining:    0.0s
# [CV]  max_depth=3, max_features=3, min_samples_split=2, n_estimators=100, score=-0.003, total=   0.2s
# [CV] max_depth=3, max_features=3, min_samples_split=2, n_estimators=100
# [22:27:27] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.9s remaining:    0.0s
# [CV]  max_depth=3, max_features=3, min_samples_split=2, n_estimators=100, score=-0.066, total=   0.2s
# [CV] max_depth=3, max_features=3, min_samples_split=2, n_estimators=150
# [22:27:27] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    1.1s remaining:    0.0s
# [CV]  max_depth=3, max_features=3, min_samples_split=2, n_estimators=150, score=-0.065, total=   0.4s
# [CV] max_depth=3, max_features=3, min_samples_split=2, n_estimators=150
# [22:27:28] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    1.5s remaining:    0.0s
# [CV]  max_depth=3, max_features=3, min_samples_split=2, n_estimators=150, score=-0.065, total=   0.4s
# [CV] max_depth=3, max_features=3, min_samples_split=2, n_estimators=150
# [22:27:28] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:    1.9s remaining:    0.0s
# [CV]  max_depth=3, max_features=3, min_samples_split=2, n_estimators=150, score=-0.023, total=   0.4s
# [CV] max_depth=3, max_features=3, min_samples_split=2, n_estimators=150
# [22:27:28] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    2.3s remaining:    0.0s
# [CV]  max_depth=3, max_features=3, min_samples_split=2, n_estimators=150, score=-0.002, total=   0.4s
# [CV] max_depth=3, max_features=3, min_samples_split=2, n_estimators=150
# [22:27:29] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:    2.6s remaining:    0.0s
# [CV]  max_depth=3, max_features=3, min_samples_split=2, n_estimators=150, score=-0.066, total=   0.4s
# [CV] max_depth=3, max_features=3, min_samples_split=2, n_estimators=200
# [22:27:29] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=3, min_samples_split=2, n_estimators=200, score=-0.065, total=   0.5s
# [CV] max_depth=3, max_features=3, min_samples_split=2, n_estimators=200
# [22:27:30] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=3, min_samples_split=2, n_estimators=200, score=-0.065, total=   0.5s
# [CV] max_depth=3, max_features=3, min_samples_split=2, n_estimators=200
# [22:27:30] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=3, min_samples_split=2, n_estimators=200, score=-0.043, total=   0.6s
# [CV] max_depth=3, max_features=3, min_samples_split=2, n_estimators=200
# [22:27:31] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=3, min_samples_split=2, n_estimators=200, score=-0.002, total=   0.5s
# [CV] max_depth=3, max_features=3, min_samples_split=2, n_estimators=200
# [22:27:31] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=3, min_samples_split=2, n_estimators=200, score=-0.066, total=   0.5s
# [CV] max_depth=3, max_features=3, min_samples_split=2, n_estimators=250
# [22:27:32] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=3, min_samples_split=2, n_estimators=250, score=-0.065, total=   0.5s
# [CV] max_depth=3, max_features=3, min_samples_split=2, n_estimators=250
# [22:27:32] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=3, min_samples_split=2, n_estimators=250, score=-0.065, total=   0.5s
# [CV] max_depth=3, max_features=3, min_samples_split=2, n_estimators=250
# [22:27:33] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=3, min_samples_split=2, n_estimators=250, score=-0.054, total=   0.6s
# [CV] max_depth=3, max_features=3, min_samples_split=2, n_estimators=250
# [22:27:33] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=3, min_samples_split=2, n_estimators=250, score=-0.002, total=   0.6s
# [CV] max_depth=3, max_features=3, min_samples_split=2, n_estimators=250
# [22:27:34] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=3, min_samples_split=2, n_estimators=250, score=-0.066, total=   0.5s
# [CV] max_depth=3, max_features=3, min_samples_split=5, n_estimators=100
# [22:27:34] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=3, min_samples_split=5, n_estimators=100, score=-0.065, total=   0.2s
# [CV] max_depth=3, max_features=3, min_samples_split=5, n_estimators=100
# [22:27:35] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=3, min_samples_split=5, n_estimators=100, score=-0.065, total=   0.2s
# [CV] max_depth=3, max_features=3, min_samples_split=5, n_estimators=100
# [22:27:35] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=3, min_samples_split=5, n_estimators=100, score=-0.005, total=   0.2s
# [CV] max_depth=3, max_features=3, min_samples_split=5, n_estimators=100
# [22:27:35] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=3, min_samples_split=5, n_estimators=100, score=-0.003, total=   0.2s
# [CV] max_depth=3, max_features=3, min_samples_split=5, n_estimators=100
# [22:27:35] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=3, min_samples_split=5, n_estimators=100, score=-0.066, total=   0.2s
# [CV] max_depth=3, max_features=3, min_samples_split=5, n_estimators=150
# [22:27:35] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=3, min_samples_split=5, n_estimators=150, score=-0.065, total=   0.3s
# [CV] max_depth=3, max_features=3, min_samples_split=5, n_estimators=150
# [22:27:36] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=3, min_samples_split=5, n_estimators=150, score=-0.065, total=   0.4s
# [CV] max_depth=3, max_features=3, min_samples_split=5, n_estimators=150
# [22:27:36] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=3, min_samples_split=5, n_estimators=150, score=-0.023, total=   0.4s
# [CV] max_depth=3, max_features=3, min_samples_split=5, n_estimators=150
# [22:27:37] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=3, min_samples_split=5, n_estimators=150, score=-0.002, total=   0.3s
# [CV] max_depth=3, max_features=3, min_samples_split=5, n_estimators=150
# [22:27:37] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=3, min_samples_split=5, n_estimators=150, score=-0.066, total=   0.3s
# [CV] max_depth=3, max_features=3, min_samples_split=5, n_estimators=200
# [22:27:37] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=3, min_samples_split=5, n_estimators=200, score=-0.065, total=   0.5s
# [CV] max_depth=3, max_features=3, min_samples_split=5, n_estimators=200
# [22:27:38] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=3, min_samples_split=5, n_estimators=200, score=-0.065, total=   0.5s
# [CV] max_depth=3, max_features=3, min_samples_split=5, n_estimators=200
# [22:27:38] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=3, min_samples_split=5, n_estimators=200, score=-0.043, total=   0.6s
# [CV] max_depth=3, max_features=3, min_samples_split=5, n_estimators=200
# [22:27:39] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=3, min_samples_split=5, n_estimators=200, score=-0.002, total=   0.5s
# [CV] max_depth=3, max_features=3, min_samples_split=5, n_estimators=200
# [22:27:39] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=3, min_samples_split=5, n_estimators=200, score=-0.066, total=   0.5s
# [CV] max_depth=3, max_features=3, min_samples_split=5, n_estimators=250
# [22:27:40] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=3, min_samples_split=5, n_estimators=250, score=-0.065, total=   0.5s
# [CV] max_depth=3, max_features=3, min_samples_split=5, n_estimators=250
# [22:27:40] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=3, min_samples_split=5, n_estimators=250, score=-0.065, total=   0.5s
# [CV] max_depth=3, max_features=3, min_samples_split=5, n_estimators=250
# [22:27:41] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=3, min_samples_split=5, n_estimators=250, score=-0.054, total=   0.6s
# [CV] max_depth=3, max_features=3, min_samples_split=5, n_estimators=250
# [22:27:41] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=3, min_samples_split=5, n_estimators=250, score=-0.002, total=   0.6s
# [CV] max_depth=3, max_features=3, min_samples_split=5, n_estimators=250
# [22:27:42] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=3, min_samples_split=5, n_estimators=250, score=-0.066, total=   0.5s
# [CV] max_depth=3, max_features=3, min_samples_split=10, n_estimators=100
# [22:27:43] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=3, min_samples_split=10, n_estimators=100, score=-0.065, total=   0.2s
# [CV] max_depth=3, max_features=3, min_samples_split=10, n_estimators=100
# [22:27:43] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=3, min_samples_split=10, n_estimators=100, score=-0.065, total=   0.2s
# [CV] max_depth=3, max_features=3, min_samples_split=10, n_estimators=100
# [22:27:43] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=3, min_samples_split=10, n_estimators=100, score=-0.005, total=   0.2s
# [CV] max_depth=3, max_features=3, min_samples_split=10, n_estimators=100
# [22:27:43] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=3, min_samples_split=10, n_estimators=100, score=-0.003, total=   0.2s
# [CV] max_depth=3, max_features=3, min_samples_split=10, n_estimators=100
# [22:27:43] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=3, min_samples_split=10, n_estimators=100, score=-0.066, total=   0.2s
# [CV] max_depth=3, max_features=3, min_samples_split=10, n_estimators=150
# [22:27:44] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=3, min_samples_split=10, n_estimators=150, score=-0.065, total=   0.3s
# [CV] max_depth=3, max_features=3, min_samples_split=10, n_estimators=150
# [22:27:44] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=3, min_samples_split=10, n_estimators=150, score=-0.065, total=   0.3s
# [CV] max_depth=3, max_features=3, min_samples_split=10, n_estimators=150
# [22:27:44] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=3, min_samples_split=10, n_estimators=150, score=-0.023, total=   0.4s
# [CV] max_depth=3, max_features=3, min_samples_split=10, n_estimators=150
# [22:27:45] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=3, min_samples_split=10, n_estimators=150, score=-0.002, total=   0.4s
# [CV] max_depth=3, max_features=3, min_samples_split=10, n_estimators=150
# [22:27:45] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=3, min_samples_split=10, n_estimators=150, score=-0.066, total=   0.4s
# [CV] max_depth=3, max_features=3, min_samples_split=10, n_estimators=200
# [22:27:46] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=3, min_samples_split=10, n_estimators=200, score=-0.065, total=   0.5s
# [CV] max_depth=3, max_features=3, min_samples_split=10, n_estimators=200
# [22:27:46] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=3, min_samples_split=10, n_estimators=200, score=-0.065, total=   0.5s
# [CV] max_depth=3, max_features=3, min_samples_split=10, n_estimators=200
# [22:27:47] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=3, min_samples_split=10, n_estimators=200, score=-0.043, total=   0.5s
# [CV] max_depth=3, max_features=3, min_samples_split=10, n_estimators=200
# [22:27:47] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=3, min_samples_split=10, n_estimators=200, score=-0.002, total=   0.5s
# [CV] max_depth=3, max_features=3, min_samples_split=10, n_estimators=200
# [22:27:48] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=3, min_samples_split=10, n_estimators=200, score=-0.066, total=   0.4s
# [CV] max_depth=3, max_features=3, min_samples_split=10, n_estimators=250
# [22:27:48] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=3, min_samples_split=10, n_estimators=250, score=-0.065, total=   0.6s
# [CV] max_depth=3, max_features=3, min_samples_split=10, n_estimators=250
# [22:27:49] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=3, min_samples_split=10, n_estimators=250, score=-0.065, total=   0.5s
# [CV] max_depth=3, max_features=3, min_samples_split=10, n_estimators=250
# [22:27:49] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=3, min_samples_split=10, n_estimators=250, score=-0.054, total=   0.6s
# [CV] max_depth=3, max_features=3, min_samples_split=10, n_estimators=250
# [22:27:50] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=3, min_samples_split=10, n_estimators=250, score=-0.002, total=   0.6s
# [CV] max_depth=3, max_features=3, min_samples_split=10, n_estimators=250
# [22:27:50] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=3, min_samples_split=10, n_estimators=250, score=-0.066, total=   0.5s
# [CV] max_depth=3, max_features=4, min_samples_split=2, n_estimators=100
# [22:27:51] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=4, min_samples_split=2, n_estimators=100, score=-0.065, total=   0.2s
# [CV] max_depth=3, max_features=4, min_samples_split=2, n_estimators=100
# [22:27:51] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=4, min_samples_split=2, n_estimators=100, score=-0.065, total=   0.2s
# [CV] max_depth=3, max_features=4, min_samples_split=2, n_estimators=100
# [22:27:51] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=4, min_samples_split=2, n_estimators=100, score=-0.005, total=   0.2s
# [CV] max_depth=3, max_features=4, min_samples_split=2, n_estimators=100
# [22:27:52] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=4, min_samples_split=2, n_estimators=100, score=-0.003, total=   0.2s
# [CV] max_depth=3, max_features=4, min_samples_split=2, n_estimators=100
# [22:27:52] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=4, min_samples_split=2, n_estimators=100, score=-0.066, total=   0.2s
# [CV] max_depth=3, max_features=4, min_samples_split=2, n_estimators=150
# [22:27:52] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=4, min_samples_split=2, n_estimators=150, score=-0.065, total=   0.3s
# [CV] max_depth=3, max_features=4, min_samples_split=2, n_estimators=150
# [22:27:52] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=4, min_samples_split=2, n_estimators=150, score=-0.065, total=   0.3s
# [CV] max_depth=3, max_features=4, min_samples_split=2, n_estimators=150
# [22:27:53] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=4, min_samples_split=2, n_estimators=150, score=-0.023, total=   0.3s
# [CV] max_depth=3, max_features=4, min_samples_split=2, n_estimators=150
# [22:27:53] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=4, min_samples_split=2, n_estimators=150, score=-0.002, total=   0.3s
# [CV] max_depth=3, max_features=4, min_samples_split=2, n_estimators=150
# [22:27:53] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=4, min_samples_split=2, n_estimators=150, score=-0.066, total=   0.4s
# [CV] max_depth=3, max_features=4, min_samples_split=2, n_estimators=200
# [22:27:54] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=4, min_samples_split=2, n_estimators=200, score=-0.065, total=   0.5s
# [CV] max_depth=3, max_features=4, min_samples_split=2, n_estimators=200
# [22:27:54] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=4, min_samples_split=2, n_estimators=200, score=-0.065, total=   0.5s
# [CV] max_depth=3, max_features=4, min_samples_split=2, n_estimators=200
# [22:27:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=4, min_samples_split=2, n_estimators=200, score=-0.043, total=   0.4s
# [CV] max_depth=3, max_features=4, min_samples_split=2, n_estimators=200
# [22:27:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=4, min_samples_split=2, n_estimators=200, score=-0.002, total=   0.5s
# [CV] max_depth=3, max_features=4, min_samples_split=2, n_estimators=200
# [22:27:56] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=4, min_samples_split=2, n_estimators=200, score=-0.066, total=   0.4s
# [CV] max_depth=3, max_features=4, min_samples_split=2, n_estimators=250
# [22:27:56] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=4, min_samples_split=2, n_estimators=250, score=-0.065, total=   0.5s
# [CV] max_depth=3, max_features=4, min_samples_split=2, n_estimators=250
# [22:27:57] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=4, min_samples_split=2, n_estimators=250, score=-0.065, total=   0.5s
# [CV] max_depth=3, max_features=4, min_samples_split=2, n_estimators=250
# [22:27:57] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=4, min_samples_split=2, n_estimators=250, score=-0.054, total=   0.6s
# [CV] max_depth=3, max_features=4, min_samples_split=2, n_estimators=250
# [22:27:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=4, min_samples_split=2, n_estimators=250, score=-0.002, total=   0.5s
# [CV] max_depth=3, max_features=4, min_samples_split=2, n_estimators=250
# [22:27:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=4, min_samples_split=2, n_estimators=250, score=-0.066, total=   0.5s
# [CV] max_depth=3, max_features=4, min_samples_split=5, n_estimators=100
# [22:27:59] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=4, min_samples_split=5, n_estimators=100, score=-0.065, total=   0.2s
# [CV] max_depth=3, max_features=4, min_samples_split=5, n_estimators=100
# [22:27:59] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=4, min_samples_split=5, n_estimators=100, score=-0.065, total=   0.2s
# [CV] max_depth=3, max_features=4, min_samples_split=5, n_estimators=100
# [22:27:59] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=4, min_samples_split=5, n_estimators=100, score=-0.005, total=   0.2s
# [CV] max_depth=3, max_features=4, min_samples_split=5, n_estimators=100
# [22:27:59] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=4, min_samples_split=5, n_estimators=100, score=-0.003, total=   0.2s
# [CV] max_depth=3, max_features=4, min_samples_split=5, n_estimators=100
# [22:28:00] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=4, min_samples_split=5, n_estimators=100, score=-0.066, total=   0.2s
# [CV] max_depth=3, max_features=4, min_samples_split=5, n_estimators=150
# [22:28:00] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=4, min_samples_split=5, n_estimators=150, score=-0.065, total=   0.3s
# [CV] max_depth=3, max_features=4, min_samples_split=5, n_estimators=150
# [22:28:00] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=4, min_samples_split=5, n_estimators=150, score=-0.065, total=   0.3s
# [CV] max_depth=3, max_features=4, min_samples_split=5, n_estimators=150
# [22:28:01] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=4, min_samples_split=5, n_estimators=150, score=-0.023, total=   0.3s
# [CV] max_depth=3, max_features=4, min_samples_split=5, n_estimators=150
# [22:28:01] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=4, min_samples_split=5, n_estimators=150, score=-0.002, total=   0.3s
# [CV] max_depth=3, max_features=4, min_samples_split=5, n_estimators=150
# [22:28:01] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=4, min_samples_split=5, n_estimators=150, score=-0.066, total=   0.4s
# [CV] max_depth=3, max_features=4, min_samples_split=5, n_estimators=200
# [22:28:02] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=4, min_samples_split=5, n_estimators=200, score=-0.065, total=   0.4s
# [CV] max_depth=3, max_features=4, min_samples_split=5, n_estimators=200
# [22:28:02] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=4, min_samples_split=5, n_estimators=200, score=-0.065, total=   0.4s
# [CV] max_depth=3, max_features=4, min_samples_split=5, n_estimators=200
# [22:28:02] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=4, min_samples_split=5, n_estimators=200, score=-0.043, total=   0.5s
# [CV] max_depth=3, max_features=4, min_samples_split=5, n_estimators=200
# [22:28:03] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=4, min_samples_split=5, n_estimators=200, score=-0.002, total=   0.5s
# [CV] max_depth=3, max_features=4, min_samples_split=5, n_estimators=200
# [22:28:03] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=4, min_samples_split=5, n_estimators=200, score=-0.066, total=   0.5s
# [CV] max_depth=3, max_features=4, min_samples_split=5, n_estimators=250
# [22:28:04] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=4, min_samples_split=5, n_estimators=250, score=-0.065, total=   0.5s
# [CV] max_depth=3, max_features=4, min_samples_split=5, n_estimators=250
# [22:28:04] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=4, min_samples_split=5, n_estimators=250, score=-0.065, total=   0.5s
# [CV] max_depth=3, max_features=4, min_samples_split=5, n_estimators=250
# [22:28:05] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=4, min_samples_split=5, n_estimators=250, score=-0.054, total=   0.6s
# [CV] max_depth=3, max_features=4, min_samples_split=5, n_estimators=250
# [22:28:06] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=4, min_samples_split=5, n_estimators=250, score=-0.002, total=   0.6s
# [CV] max_depth=3, max_features=4, min_samples_split=5, n_estimators=250
# [22:28:06] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=4, min_samples_split=5, n_estimators=250, score=-0.066, total=   0.5s
# [CV] max_depth=3, max_features=4, min_samples_split=10, n_estimators=100
# [22:28:07] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=4, min_samples_split=10, n_estimators=100, score=-0.065, total=   0.3s
# [CV] max_depth=3, max_features=4, min_samples_split=10, n_estimators=100
# [22:28:07] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=4, min_samples_split=10, n_estimators=100, score=-0.065, total=   0.3s
# [CV] max_depth=3, max_features=4, min_samples_split=10, n_estimators=100
# [22:28:07] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=4, min_samples_split=10, n_estimators=100, score=-0.005, total=   0.3s
# [CV] max_depth=3, max_features=4, min_samples_split=10, n_estimators=100
# [22:28:07] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=4, min_samples_split=10, n_estimators=100, score=-0.003, total=   0.3s
# [CV] max_depth=3, max_features=4, min_samples_split=10, n_estimators=100
# [22:28:08] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=4, min_samples_split=10, n_estimators=100, score=-0.066, total=   0.3s
# [CV] max_depth=3, max_features=4, min_samples_split=10, n_estimators=150
# [22:28:08] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=4, min_samples_split=10, n_estimators=150, score=-0.065, total=   0.4s
# [CV] max_depth=3, max_features=4, min_samples_split=10, n_estimators=150
# [22:28:08] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=4, min_samples_split=10, n_estimators=150, score=-0.065, total=   0.3s
# [CV] max_depth=3, max_features=4, min_samples_split=10, n_estimators=150
# [22:28:09] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=4, min_samples_split=10, n_estimators=150, score=-0.023, total=   0.3s
# [CV] max_depth=3, max_features=4, min_samples_split=10, n_estimators=150
# [22:28:09] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=4, min_samples_split=10, n_estimators=150, score=-0.002, total=   0.3s
# [CV] max_depth=3, max_features=4, min_samples_split=10, n_estimators=150
# [22:28:09] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=4, min_samples_split=10, n_estimators=150, score=-0.066, total=   0.4s
# [CV] max_depth=3, max_features=4, min_samples_split=10, n_estimators=200
# [22:28:10] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=4, min_samples_split=10, n_estimators=200, score=-0.065, total=   0.4s
# [CV] max_depth=3, max_features=4, min_samples_split=10, n_estimators=200
# [22:28:10] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=4, min_samples_split=10, n_estimators=200, score=-0.065, total=   0.5s
# [CV] max_depth=3, max_features=4, min_samples_split=10, n_estimators=200
# [22:28:11] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=4, min_samples_split=10, n_estimators=200, score=-0.043, total=   0.5s
# [CV] max_depth=3, max_features=4, min_samples_split=10, n_estimators=200
# [22:28:11] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=4, min_samples_split=10, n_estimators=200, score=-0.002, total=   0.5s
# [CV] max_depth=3, max_features=4, min_samples_split=10, n_estimators=200
# [22:28:12] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=4, min_samples_split=10, n_estimators=200, score=-0.066, total=   0.4s
# [CV] max_depth=3, max_features=4, min_samples_split=10, n_estimators=250
# [22:28:12] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=4, min_samples_split=10, n_estimators=250, score=-0.065, total=   0.5s
# [CV] max_depth=3, max_features=4, min_samples_split=10, n_estimators=250
# [22:28:13] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=4, min_samples_split=10, n_estimators=250, score=-0.065, total=   0.5s
# [CV] max_depth=3, max_features=4, min_samples_split=10, n_estimators=250
# [22:28:13] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=4, min_samples_split=10, n_estimators=250, score=-0.054, total=   0.6s
# [CV] max_depth=3, max_features=4, min_samples_split=10, n_estimators=250
# [22:28:14] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=4, min_samples_split=10, n_estimators=250, score=-0.002, total=   0.6s
# [CV] max_depth=3, max_features=4, min_samples_split=10, n_estimators=250
# [22:28:14] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=3, max_features=4, min_samples_split=10, n_estimators=250, score=-0.066, total=   0.6s
# [CV] max_depth=5, max_features=3, min_samples_split=2, n_estimators=100
# [22:28:15] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=5, max_features=3, min_samples_split=2, n_estimators=100, score=-0.065, total=   0.4s
# [CV] max_depth=5, max_features=3, min_samples_split=2, n_estimators=100
# [22:28:15] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=5, max_features=3, min_samples_split=2, n_estimators=100, score=-0.065, total=   0.4s
# [CV] max_depth=5, max_features=3, min_samples_split=2, n_estimators=100
# [22:28:16] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=5, max_features=3, min_samples_split=2, n_estimators=100, score=-0.014, total=   0.4s
# [CV] max_depth=5, max_features=3, min_samples_split=2, n_estimators=100
# [22:28:16] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=5, max_features=3, min_samples_split=2, n_estimators=100, score=-0.002, total=   0.4s
# [CV] max_depth=5, max_features=3, min_samples_split=2, n_estimators=100
# [22:28:17] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=5, max_features=3, min_samples_split=2, n_estimators=100, score=-0.066, total=   0.5s
# [CV] max_depth=5, max_features=3, min_samples_split=2, n_estimators=150
# [22:28:17] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=5, max_features=3, min_samples_split=2, n_estimators=150, score=-0.065, total=   0.5s
# [CV] max_depth=5, max_features=3, min_samples_split=2, n_estimators=150
# [22:28:18] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=5, max_features=3, min_samples_split=2, n_estimators=150, score=-0.065, total=   0.5s
# [CV] max_depth=5, max_features=3, min_samples_split=2, n_estimators=150
# [22:28:18] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=5, max_features=3, min_samples_split=2, n_estimators=150, score=-0.022, total=   0.5s
# [CV] max_depth=5, max_features=3, min_samples_split=2, n_estimators=150
# [22:28:19] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=5, max_features=3, min_samples_split=2, n_estimators=150, score=-0.002, total=   0.6s
# [CV] max_depth=5, max_features=3, min_samples_split=2, n_estimators=150
# [22:28:19] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=5, max_features=3, min_samples_split=2, n_estimators=150, score=-0.066, total=   0.5s
# [CV] max_depth=5, max_features=3, min_samples_split=2, n_estimators=200
# [22:28:20] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=5, max_features=3, min_samples_split=2, n_estimators=200, score=-0.065, total=   0.5s
# [CV] max_depth=5, max_features=3, min_samples_split=2, n_estimators=200
# [22:28:20] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=5, max_features=3, min_samples_split=2, n_estimators=200, score=-0.065, total=   0.6s
# [CV] max_depth=5, max_features=3, min_samples_split=2, n_estimators=200
# [22:28:21] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=5, max_features=3, min_samples_split=2, n_estimators=200, score=-0.022, total=   0.6s
# [CV] max_depth=5, max_features=3, min_samples_split=2, n_estimators=200
# [22:28:21] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=5, max_features=3, min_samples_split=2, n_estimators=200, score=-0.002, total=   0.6s
# [CV] max_depth=5, max_features=3, min_samples_split=2, n_estimators=200
# [22:28:22] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=5, max_features=3, min_samples_split=2, n_estimators=200, score=-0.066, total=   0.5s
# [CV] max_depth=5, max_features=3, min_samples_split=2, n_estimators=250
# [22:28:22] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=5, max_features=3, min_samples_split=2, n_estimators=250, score=-0.065, total=   0.6s
# [CV] max_depth=5, max_features=3, min_samples_split=2, n_estimators=250
# [22:28:23] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=5, max_features=3, min_samples_split=2, n_estimators=250, score=-0.065, total=   0.6s
# [CV] max_depth=5, max_features=3, min_samples_split=2, n_estimators=250
# [22:28:24] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=5, max_features=3, min_samples_split=2, n_estimators=250, score=-0.022, total=   0.6s
# [CV] max_depth=5, max_features=3, min_samples_split=2, n_estimators=250
# [22:28:24] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=5, max_features=3, min_samples_split=2, n_estimators=250, score=-0.002, total=   0.6s
# [CV] max_depth=5, max_features=3, min_samples_split=2, n_estimators=250
# [22:28:25] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=5, max_features=3, min_samples_split=2, n_estimators=250, score=-0.066, total=   0.6s
# [CV] max_depth=5, max_features=3, min_samples_split=5, n_estimators=100
# [22:28:25] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=5, max_features=3, min_samples_split=5, n_estimators=100, score=-0.065, total=   0.4s
# [CV] max_depth=5, max_features=3, min_samples_split=5, n_estimators=100
# [22:28:26] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=5, max_features=3, min_samples_split=5, n_estimators=100, score=-0.065, total=   0.4s
# [CV] max_depth=5, max_features=3, min_samples_split=5, n_estimators=100
# [22:28:26] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=5, max_features=3, min_samples_split=5, n_estimators=100, score=-0.014, total=   0.4s
# [CV] max_depth=5, max_features=3, min_samples_split=5, n_estimators=100
# [22:28:27] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=5, max_features=3, min_samples_split=5, n_estimators=100, score=-0.002, total=   0.4s
# [CV] max_depth=5, max_features=3, min_samples_split=5, n_estimators=100
# [22:28:27] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=5, max_features=3, min_samples_split=5, n_estimators=100, score=-0.066, total=   0.4s
# [CV] max_depth=5, max_features=3, min_samples_split=5, n_estimators=150
# [22:28:27] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=5, max_features=3, min_samples_split=5, n_estimators=150, score=-0.065, total=   0.5s
# [CV] max_depth=5, max_features=3, min_samples_split=5, n_estimators=150
# [22:28:28] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=5, max_features=3, min_samples_split=5, n_estimators=150, score=-0.065, total=   0.5s
# [CV] max_depth=5, max_features=3, min_samples_split=5, n_estimators=150
# [22:28:28] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=5, max_features=3, min_samples_split=5, n_estimators=150, score=-0.022, total=   0.5s
# [CV] max_depth=5, max_features=3, min_samples_split=5, n_estimators=150
# [22:28:29] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=5, max_features=3, min_samples_split=5, n_estimators=150, score=-0.002, total=   0.5s
# [CV] max_depth=5, max_features=3, min_samples_split=5, n_estimators=150
# [22:28:29] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=5, max_features=3, min_samples_split=5, n_estimators=150, score=-0.066, total=   0.4s
# [CV] max_depth=5, max_features=3, min_samples_split=5, n_estimators=200
# [22:28:30] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=5, max_features=3, min_samples_split=5, n_estimators=200, score=-0.065, total=   0.5s
# [CV] max_depth=5, max_features=3, min_samples_split=5, n_estimators=200
# [22:28:30] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=5, max_features=3, min_samples_split=5, n_estimators=200, score=-0.065, total=   0.5s
# [CV] max_depth=5, max_features=3, min_samples_split=5, n_estimators=200
# [22:28:31] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=5, max_features=3, min_samples_split=5, n_estimators=200, score=-0.022, total=   0.6s
# [CV] max_depth=5, max_features=3, min_samples_split=5, n_estimators=200
# [22:28:31] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=5, max_features=3, min_samples_split=5, n_estimators=200, score=-0.002, total=   0.5s
# [CV] max_depth=5, max_features=3, min_samples_split=5, n_estimators=200
# [22:28:32] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=5, max_features=3, min_samples_split=5, n_estimators=200, score=-0.066, total=   0.5s
# [CV] max_depth=5, max_features=3, min_samples_split=5, n_estimators=250
# [22:28:33] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=5, max_features=3, min_samples_split=5, n_estimators=250, score=-0.065, total=   0.5s
# [CV] max_depth=5, max_features=3, min_samples_split=5, n_estimators=250
# [22:28:33] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=5, max_features=3, min_samples_split=5, n_estimators=250, score=-0.065, total=   0.5s
# [CV] max_depth=5, max_features=3, min_samples_split=5, n_estimators=250
# ...
# [22:29:55] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=7, max_features=4, min_samples_split=2, n_estimators=150, score=-0.015, total=   0.6s
# [CV] max_depth=7, max_features=4, min_samples_split=2, n_estimators=150
# [22:29:56] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=7, max_features=4, min_samples_split=2, n_estimators=150, score=-0.000, total=   0.6s
# [CV] max_depth=7, max_features=4, min_samples_split=2, n_estimators=150
# [22:29:56] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=7, max_features=4, min_samples_split=2, n_estimators=150, score=-0.066, total=   0.6s
# [CV] max_depth=7, max_features=4, min_samples_split=2, n_estimators=200
# [22:29:57] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=7, max_features=4, min_samples_split=2, n_estimators=200, score=-0.065, total=   0.6s
# [CV] max_depth=7, max_features=4, min_samples_split=2, n_estimators=200
# [22:29:57] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=7, max_features=4, min_samples_split=2, n_estimators=200, score=-0.067, total=   0.7s
# [CV] max_depth=7, max_features=4, min_samples_split=2, n_estimators=200
# [22:29:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=7, max_features=4, min_samples_split=2, n_estimators=200, score=-0.015, total=   0.6s
# [CV] max_depth=7, max_features=4, min_samples_split=2, n_estimators=200
# [22:29:59] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=7, max_features=4, min_samples_split=2, n_estimators=200, score=-0.000, total=   0.7s
# [CV] max_depth=7, max_features=4, min_samples_split=2, n_estimators=200
# [22:30:00] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=7, max_features=4, min_samples_split=2, n_estimators=200, score=-0.066, total=   0.7s
# [CV] max_depth=7, max_features=4, min_samples_split=2, n_estimators=250
# [22:30:00] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=7, max_features=4, min_samples_split=2, n_estimators=250, score=-0.065, total=   0.7s
# [CV] max_depth=7, max_features=4, min_samples_split=2, n_estimators=250
# [22:30:01] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=7, max_features=4, min_samples_split=2, n_estimators=250, score=-0.067, total=   0.7s
# [CV] max_depth=7, max_features=4, min_samples_split=2, n_estimators=250
# [22:30:02] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=7, max_features=4, min_samples_split=2, n_estimators=250, score=-0.015, total=   0.8s
# [CV] max_depth=7, max_features=4, min_samples_split=2, n_estimators=250
# [22:30:02] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=7, max_features=4, min_samples_split=2, n_estimators=250, score=-0.000, total=   0.7s
# [CV] max_depth=7, max_features=4, min_samples_split=2, n_estimators=250
# [22:30:03] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=7, max_features=4, min_samples_split=2, n_estimators=250, score=-0.066, total=   0.7s
# [CV] max_depth=7, max_features=4, min_samples_split=5, n_estimators=100
# [22:30:04] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=7, max_features=4, min_samples_split=5, n_estimators=100, score=-0.065, total=   0.5s
# [CV] max_depth=7, max_features=4, min_samples_split=5, n_estimators=100
# [22:30:04] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=7, max_features=4, min_samples_split=5, n_estimators=100, score=-0.067, total=   0.5s
# [CV] max_depth=7, max_features=4, min_samples_split=5, n_estimators=100
# [22:30:05] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=7, max_features=4, min_samples_split=5, n_estimators=100, score=-0.015, total=   0.5s
# [CV] max_depth=7, max_features=4, min_samples_split=5, n_estimators=100
# [22:30:05] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=7, max_features=4, min_samples_split=5, n_estimators=100, score=-0.001, total=   0.5s
# [CV] max_depth=7, max_features=4, min_samples_split=5, n_estimators=100
# [22:30:06] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=7, max_features=4, min_samples_split=5, n_estimators=100, score=-0.066, total=   0.5s
# [CV] max_depth=7, max_features=4, min_samples_split=5, n_estimators=150
# [22:30:06] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=7, max_features=4, min_samples_split=5, n_estimators=150, score=-0.065, total=   0.5s
# [CV] max_depth=7, max_features=4, min_samples_split=5, n_estimators=150
# [22:30:07] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=7, max_features=4, min_samples_split=5, n_estimators=150, score=-0.067, total=   0.5s
# [CV] max_depth=7, max_features=4, min_samples_split=5, n_estimators=150
# [22:30:07] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=7, max_features=4, min_samples_split=5, n_estimators=150, score=-0.015, total=   0.6s
# [CV] max_depth=7, max_features=4, min_samples_split=5, n_estimators=150
# [22:30:08] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=7, max_features=4, min_samples_split=5, n_estimators=150, score=-0.000, total=   0.6s
# [CV] max_depth=7, max_features=4, min_samples_split=5, n_estimators=150
# [22:30:08] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=7, max_features=4, min_samples_split=5, n_estimators=150, score=-0.066, total=   0.6s
# [CV] max_depth=7, max_features=4, min_samples_split=5, n_estimators=200
# [22:30:09] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=7, max_features=4, min_samples_split=5, n_estimators=200, score=-0.065, total=   0.6s
# [CV] max_depth=7, max_features=4, min_samples_split=5, n_estimators=200
# [22:30:10] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=7, max_features=4, min_samples_split=5, n_estimators=200, score=-0.067, total=   0.7s
# [CV] max_depth=7, max_features=4, min_samples_split=5, n_estimators=200
# [22:30:10] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=7, max_features=4, min_samples_split=5, n_estimators=200, score=-0.015, total=   0.6s
# [CV] max_depth=7, max_features=4, min_samples_split=5, n_estimators=200
# [22:30:11] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=7, max_features=4, min_samples_split=5, n_estimators=200, score=-0.000, total=   0.6s
# [CV] max_depth=7, max_features=4, min_samples_split=5, n_estimators=200
# [22:30:12] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=7, max_features=4, min_samples_split=5, n_estimators=200, score=-0.066, total=   0.6s
# [CV] max_depth=7, max_features=4, min_samples_split=5, n_estimators=250
# [22:30:12] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=7, max_features=4, min_samples_split=5, n_estimators=250, score=-0.065, total=   0.6s
# [CV] max_depth=7, max_features=4, min_samples_split=5, n_estimators=250
# [22:30:13] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=7, max_features=4, min_samples_split=5, n_estimators=250, score=-0.067, total=   0.6s
# [CV] max_depth=7, max_features=4, min_samples_split=5, n_estimators=250
# [22:30:13] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=7, max_features=4, min_samples_split=5, n_estimators=250, score=-0.015, total=   0.7s
# [CV] max_depth=7, max_features=4, min_samples_split=5, n_estimators=250
# [22:30:14] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=7, max_features=4, min_samples_split=5, n_estimators=250, score=-0.000, total=   0.7s
# [CV] max_depth=7, max_features=4, min_samples_split=5, n_estimators=250
# [22:30:15] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=7, max_features=4, min_samples_split=5, n_estimators=250, score=-0.066, total=   0.7s
# [CV] max_depth=7, max_features=4, min_samples_split=10, n_estimators=100
# [22:30:16] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=7, max_features=4, min_samples_split=10, n_estimators=100, score=-0.065, total=   0.6s
# [CV] max_depth=7, max_features=4, min_samples_split=10, n_estimators=100
# [22:30:16] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=7, max_features=4, min_samples_split=10, n_estimators=100, score=-0.067, total=   0.5s
# [CV] max_depth=7, max_features=4, min_samples_split=10, n_estimators=100
# [22:30:17] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=7, max_features=4, min_samples_split=10, n_estimators=100, score=-0.015, total=   0.5s
# [CV] max_depth=7, max_features=4, min_samples_split=10, n_estimators=100
# [22:30:17] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=7, max_features=4, min_samples_split=10, n_estimators=100, score=-0.001, total=   0.5s
# [CV] max_depth=7, max_features=4, min_samples_split=10, n_estimators=100
# [22:30:18] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=7, max_features=4, min_samples_split=10, n_estimators=100, score=-0.066, total=   0.5s
# [CV] max_depth=7, max_features=4, min_samples_split=10, n_estimators=150
# [22:30:18] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=7, max_features=4, min_samples_split=10, n_estimators=150, score=-0.065, total=   0.6s
# [CV] max_depth=7, max_features=4, min_samples_split=10, n_estimators=150
# [22:30:19] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=7, max_features=4, min_samples_split=10, n_estimators=150, score=-0.067, total=   0.7s
# [CV] max_depth=7, max_features=4, min_samples_split=10, n_estimators=150
# [22:30:19] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=7, max_features=4, min_samples_split=10, n_estimators=150, score=-0.015, total=   0.7s
# [CV] max_depth=7, max_features=4, min_samples_split=10, n_estimators=150
# [22:30:20] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=7, max_features=4, min_samples_split=10, n_estimators=150, score=-0.000, total=   0.7s
# [CV] max_depth=7, max_features=4, min_samples_split=10, n_estimators=150
# [22:30:21] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=7, max_features=4, min_samples_split=10, n_estimators=150, score=-0.066, total=   0.7s
# [CV] max_depth=7, max_features=4, min_samples_split=10, n_estimators=200
# [22:30:21] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=7, max_features=4, min_samples_split=10, n_estimators=200, score=-0.065, total=   0.7s
# [CV] max_depth=7, max_features=4, min_samples_split=10, n_estimators=200
# [22:30:22] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=7, max_features=4, min_samples_split=10, n_estimators=200, score=-0.067, total=   0.7s
# [CV] max_depth=7, max_features=4, min_samples_split=10, n_estimators=200
# [22:30:23] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=7, max_features=4, min_samples_split=10, n_estimators=200, score=-0.015, total=   0.7s
# [CV] max_depth=7, max_features=4, min_samples_split=10, n_estimators=200
# [22:30:23] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=7, max_features=4, min_samples_split=10, n_estimators=200, score=-0.000, total=   0.6s
# [CV] max_depth=7, max_features=4, min_samples_split=10, n_estimators=200
# [22:30:24] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=7, max_features=4, min_samples_split=10, n_estimators=200, score=-0.066, total=   0.6s
# [CV] max_depth=7, max_features=4, min_samples_split=10, n_estimators=250
# [22:30:25] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=7, max_features=4, min_samples_split=10, n_estimators=250, score=-0.065, total=   0.6s
# [CV] max_depth=7, max_features=4, min_samples_split=10, n_estimators=250
# [22:30:25] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=7, max_features=4, min_samples_split=10, n_estimators=250, score=-0.067, total=   0.6s
# [CV] max_depth=7, max_features=4, min_samples_split=10, n_estimators=250
# [22:30:26] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=7, max_features=4, min_samples_split=10, n_estimators=250, score=-0.015, total=   0.7s
# [CV] max_depth=7, max_features=4, min_samples_split=10, n_estimators=250
# [22:30:27] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=7, max_features=4, min_samples_split=10, n_estimators=250, score=-0.000, total=   0.7s
# [CV] max_depth=7, max_features=4, min_samples_split=10, n_estimators=250
# [22:30:27] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=7, max_features=4, min_samples_split=10, n_estimators=250, score=-0.066, total=   0.7s
# [22:30:28] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [Parallel(n_jobs=1)]: Done 360 out of 360 | elapsed:  3.0min finished
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-9c96b1868122> in <module>
#       5 print(model)
#       6 model.fit(x_train, y_train)
# ----> 7 model_cv=cv.best_estimator_
#       8 cv_result=[sorted(model.cv_results_.keys())]
#       9
#
# NameError: name 'cv' is not defined

# %%
model_cv=model.best_estimator_


print(model_cv)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0,
#              importance_type='gain', learning_rate=0.1, max_delta_step=2,
#              max_depth=3, max_features=3, min_child_weight=1,
#              min_samples_split=2, missing=None, n_estimators=100, n_jobs=1,
#              nthread=None, objective='reg:linear', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=100, seed=None, silent=None,
#              subsample=1, verbosity=1)

# %%
rmse
# Out:
# [-0.0003292468022562548, -0.00011040698009310291, -0.2800075228639492]

# %%
model_cv.fit(np.array(x_train), y_train)
# Out:
# [22:31:49] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0,
#              importance_type='gain', learning_rate=0.1, max_delta_step=2,
#              max_depth=3, max_features=3, min_child_weight=1,
#              min_samples_split=2, missing=None, n_estimators=100, n_jobs=1,
#              nthread=None, objective='reg:linear', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=100, seed=None, silent=None,
#              subsample=1, verbosity=1)

# %%
rmse
# Out:
# [-31671.886124990444,
#  -189542.96275596152,
#  -72505.98063787617,
#  -44015.70053434704,
#  -35827.00308720544,
#  -43040.371427160375,
#  -47340.960503800874]

# %% [markdown]
# ## Test set predictions

# %%
selected_columns
# Out:
# Index(['MSSubClass', 'LotFrontage', 'LotArea', 'Street', 'Neighborhood',
#        'Condition2', 'BldgType', 'HouseStyle', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'RoofMatl', 'Exterior1st', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'BsmtQual', 'BsmtExposure', 'BsmtUnfSF', '1stFlrSF',
#        '2ndFlrSF', 'BsmtFullBath', 'BedroomAbvGr', 'KitchenAbvGr',
#        'KitchenQual', 'TotRmsAbvGrd', 'Functional', 'Fireplaces',
#        'GarageFinish', 'GarageCars', 'WoodDeckSF', 'ScreenPorch', 'PoolArea',
#        'YrSold', 'SaleCondition'],
#       dtype='object')

# %%
model_cv.feature_importances_
# Out:
# array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 4.9635203e-04,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 4.3960928e-05, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 1.8361893e-02, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 2.2446728e-05, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 4.2973867e-01, 2.1981930e-05, 4.0012041e-01,
#        1.8944671e-02, 6.3485026e-02, 6.8764612e-02], dtype=float32)

# %%
test[selected_columns].info()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-45-68730cd12e2d> in <module>
# ----> 1 test[selected_columns].info()
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1550
#    1551         self._validate_read_indexer(
# -> 1552             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1553         )
#    1554         return keyarr, indexer
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1643             if not (self.name == "loc" and not raise_missing):
#    1644                 not_found = list(set(key) - set(ax))
# -> 1645                 raise KeyError(f"{not_found} not in index")
#    1646
#    1647             # we skip the warning on Categorical/Interval
#
# KeyError: "['Abnorml', 'NA', 'Mod', 'Ex', 'AdjLand', 'WD', 'BLQ', 'TA', 'Grvl', 'Feedr', 'Family', 'Alloca', 'N', 'Gd', 'Fa', 'Gtl', 'Tar&Grv', 'Y', 'Po', 'FR2', 'New', 'VinylSd', 'Pave'] not in index"

# %%
#test['Neighborhood'].replace({'NAmes':'Names'},inplace=True)
test['Neighborhood'].value_counts()

for i in set(categorical_vars).intersection(set(selected_columns)):
    print(test[i].value_counts(dropna=False))
# Out:
# Normal     1204
# Partial     120
# Abnorml      89
# Family       26
# Alloca       12
# AdjLand       8
# Name: SaleCondition, dtype: int64
# NAmes      218
# OldTown    126
# CollgCr    117
# Somerst     96
# Edwards     94
# NridgHt     89
# Gilbert     86
# Sawyer      77
# SawyerW     66
# Mitchel     65
# NWAmes      58
# IDOTRR      56
# Crawfor     52
# BrkSide     50
# Timber      34
# NoRidge     30
# StoneBr     26
# SWISU       23
# MeadowV     20
# ClearCr     16
# BrDale      14
# NPkVill     14
# Veenker     13
# Blmngtn     11
# Blueste      8
# Name: Neighborhood, dtype: int64
# 1Story    745
# 2Story    427
# 1.5Fin    160
# SLvl       63
# SFoyer     46
# 2.5Unf     13
# 1.5Unf      5
# Name: HouseStyle, dtype: int64
# VinylSd    511
# MetalSd    230
# HdBoard    220
# Wd Sdng    205
# Plywood    113
# CemntBd     65
# BrkFace     37
# WdShing     30
# AsbShng     24
# Stucco      18
# BrkComm      4
# CBlock       1
# AsphShn      1
# Name: Exterior1st, dtype: int64
# 1Fam      1205
# TwnhsE     113
# Duplex      57
# Twnhs       53
# 2fmCon      31
# Name: BldgType, dtype: int64
# No    953
# Av    197
# Gd    142
# Mn    125
# NA     42
# Name: BsmtExposure, dtype: int64
# TA    892
# Gd    491
# Ex     55
# Fa     21
# Name: ExterQual, dtype: int64
# Norm      1444
# Feedr        7
# PosA         3
# Artery       3
# PosN         2
# Name: Condition2, dtype: int64
# Unf    625
# RFn    389
# Fin    367
# NA      78
# Name: GarageFinish, dtype: int64
# CompShg    1442
# Tar&Grv      12
# WdShake       4
# WdShngl       1
# Name: RoofMatl, dtype: int64
# TA    634
# Gd    591
# Ex    137
# Fa     53
# NA     44
# Name: BsmtQual, dtype: int64
# TA    758
# Gd    565
# Ex    105
# Fa     31
# Name: KitchenQual, dtype: int64
# Typ     1359
# Min2      36
# Min1      34
# Mod       20
# Maj1       5
# Maj2       4
# Sev        1
# Name: Functional, dtype: int64
# Pave    1453
# Grvl       6
# Name: Street, dtype: int64
# None       894
# BrkFace    434
# Stone      121
# BrkCmn      10
# Name: MasVnrType, dtype: int64

# %%
data = pd.DataFrame(data = test, columns = selected_columns)
x_test=data.values
x_test= scaler.transform(x_test)
test['SalePrice']=model.predict(x_test)

# %%
test[['Id', 'SalePrice']].to_csv('test_submission.csv',index=False)
